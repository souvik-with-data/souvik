# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("/content/IPL_dataset.csv")
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2      3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4      5    2008     Kolkata  20-04-2008        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  22-05-2016       Delhi Daredevils
# 573  574    2016   Bangalore  24-05-2016          Gujarat Lions
# 574  575    2016       Delhi  25-05-2016    Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-2016          Gujarat Lions
# 576  577    2016   Bangalore  29-05-2016    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2   3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4   5    2008     Kolkata  20-04-2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.shape
# Out:
# (577, 18)

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  22-05-2016     Delhi Daredevils
# 573  574    2016  Bangalore  24-05-2016        Gujarat Lions
# 574  575    2016      Delhi  25-05-2016  Sunrisers Hyderabad
# 575  576    2016      Delhi  27-05-2016        Gujarat Lions
# 576  577    2016  Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=577, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     12
# int64       5
# float64     1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df['winner']
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 572    Royal Challengers Bangalore
# 573    Royal Challengers Bangalore
# 574            Sunrisers Hyderabad
# 575            Sunrisers Hyderabad
# 576            Sunrisers Hyderabad
# Name: winner, Length: 577, dtype: object

# %%
df['win_by_runs'].max()
# Out:
# 144

# %%
df['win_by_runs'].min()
# Out:
# 0

# %%
df['win_by_runs'].mean()
# Out:
# 13.7157712305026

# %%
df['win_by_wickets'].describe()
# Out:
# count    577.000000
# mean       3.363951
# std        3.416049
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%        6.000000
# max       10.000000
# Name: win_by_wickets, dtype: float64

# %%
df.sort_values(by="win_by_runs")
# Out:
#       id  season           city        date                        team1  \
# 194  195    2011         Mumbai  20-04-2011                Pune Warriors
# 256  257    2012  Visakhapatnam  09-04-2012              Deccan Chargers
# 455  456    2014         Mumbai  28-05-2014               Mumbai Indians
# 457  458    2014      Bangalore  01-06-2014              Kings XI Punjab
# 458  459    2015        Kolkata  08-04-2015               Mumbai Indians
# ..   ...     ...            ...         ...                          ...
# 236  237    2011     Dharamsala  17-05-2011              Kings XI Punjab
# 351  352    2013      Bangalore  23-04-2013  Royal Challengers Bangalore
# 497  498    2015      Bangalore  06-05-2015  Royal Challengers Bangalore
# 0      1    2008      Bangalore  18-04-2008        Kolkata Knight Riders
# 560  561    2016      Bangalore  14-05-2016  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.sort_values(by="win_by_runs").tail()
# Out:
#       id  season        city        date                        team1  \
# 236  237    2011  Dharamsala  17-05-2011              Kings XI Punjab
# 351  352    2013   Bangalore  23-04-2013  Royal Challengers Bangalore
# 497  498    2015   Bangalore  06-05-2015  Royal Challengers Bangalore
# 0      1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 560  561    2016   Bangalore  14-05-2016  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 236  Royal Challengers Bangalore              Kings XI Punjab           bat
# 351                Pune Warriors                Pune Warriors         field
# 497              Kings XI Punjab              Kings XI Punjab         field
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 560                Gujarat Lions                Gujarat Lions         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df['city'].describe()
# Out:
# count        570
# unique        30
# top       Mumbai
# freq          77
# Name: city, dtype: object

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Port Elizabeth     7
# Cape Town          7
# Ranchi             7
# Abu Dhabi          7
# Sharjah            6
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: count, dtype: int64

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
df['win_by_runs'][df.IPL<=140].value_counts()
# Out:
# city
# Mumbai            77
# Bangalore         57
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Port Elizabeth     7
# Cape Town          7
# Ranchi             7
# Abu Dhabi          7
# Sharjah            6
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: count, dtype: int64

# %%
plt.plot('win_by_runs',data=df)
plt.show()

# %%
plt.plot('win_by_wickets','*',data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df.fillna('kolkata',inplace=True)
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
sns.displot(x='winner',data=df)

# %%
corr=df[['id','win_by_runs','win_by_wickets']].corr()
print(corr)
sns.heatmap(corr)
# Out:
#                       id  win_by_runs  win_by_wickets
# id              1.000000    -0.014813       -0.012804
# win_by_runs    -0.014813     1.000000       -0.572839
# win_by_wickets -0.012804    -0.572839        1.000000
# <Axes: >

# %%
sns.histplot(data=df,x='winner')
# Out:
# <Axes: xlabel='winner', ylabel='Count'>

# %%
winner=df['winner']
plt.plot(winner,color='green',label='winner')
plt.legend()
plt.show()

# %%
sns.boxplot(df['winner'])
# Out:
# <Axes: ylabel='winner'>

# %%
df['city']
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 572        Raipur
# 573     Bangalore
# 574         Delhi
# 575         Delhi
# 576     Bangalore
# Name: city, Length: 577, dtype: object

# %%
sns.scatterplot(x='city',y='winner',data=df)
# Out:
# <Axes: xlabel='city', ylabel='winner'>

# %%
sns.scatterplot(x='city',y='winner',data=df)
# Out:
# <Axes: xlabel='city', ylabel='winner'>

# %%
sns.histplot(x="winner",data=df)
# Out:
# <Axes: xlabel='winner', ylabel='Count'>

# %%
sns.scatterplot(x='city',y='winner',data=df,hue='season')
# Out:
# <Axes: xlabel='city', ylabel='winner'>

# %%
sns.histplot(data=df,x='winner')
# Out:
# <Axes: xlabel='winner', ylabel='Count'>

# %%
df.groupby("city").count()
# Out:
#                 id  season  date  team1  team2  toss_winner  toss_decision  \
# city
# Abu Dhabi        7       7     7      7      7            7              7
# Ahmedabad       12      12    12     12     12           12             12
# Bangalore       58      58    58     58     58           58             58
# Bloemfontein     2       2     2      2      2            2              2
# Cape Town        7       7     7      7      7            7              7
# Centurion       12      12    12     12     12           12             12
# Chandigarh      42      42    42     42     42           42             42
# Chennai         48      48    48     48     48           48             48
# Cuttack          7       7     7      7      7            7              7
# Delhi           53      53    53     53     53           53             53
# Dharamsala       9       9     9      9      9            9              9
# ...

# %%
df.nunique()
# Out:
# id                 577
# season               9
# city                30
# date               407
# team1               13
# team2               13
# toss_winner         13
# toss_decision        2
# result               3
# dl_applied           2
# winner              13
# win_by_runs         83
# win_by_wickets      11
# player_of_match    187
# venue               35
# umpire1             43
# umpire2             45
# umpire3              0
# dtype: int64

# %%
sns.barplot(x='city',y='winner',data=df)
# Out:
# <Axes: xlabel='city', ylabel='winner'>

# %%
sns.jointplot(x='city',y='player_of_match',data=df)

# %%
sns.pairplot(df,hue="city")

# %%
sns.pairplot(df,hue="season",palette="Blues")

# %%
df.sort_values(by='win_by_runs',ascending=False)
# Out:
#       id  season        city        date                        team1  \
# 560  561    2016   Bangalore  14-05-2016  Royal Challengers Bangalore
# 0      1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 497  498    2015   Bangalore  06-05-2015  Royal Challengers Bangalore
# 351  352    2013   Bangalore  23-04-2013  Royal Challengers Bangalore
# 236  237    2011  Dharamsala  17-05-2011              Kings XI Punjab
# ..   ...     ...         ...         ...                          ...
# 328  329    2013   Hyderabad  07-04-2013  Royal Challengers Bangalore
# 327  328    2013        Pune  07-04-2013                Pune Warriors
# 108  109    2009      Durban  20-05-2009             Rajasthan Royals
# 322  323    2013     Kolkata  03-04-2013             Delhi Daredevils
# 382  383    2013      Jaipur  12-05-2013          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Port Elizabeth     7
# Cape Town          7
# Ranchi             7
# Abu Dhabi          7
# Sharjah            6
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: count, dtype: int64

# %%
sns.countplot(x='city',data=df)
# Out:
# <Axes: xlabel='city', ylabel='count'>

# %%
sns.countplot(x='city',data=df,hue='winner')
# Out:
# <Axes: xlabel='city', ylabel='count'>

# %%
sns.histplot(x='',data=df)

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2   3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4   5    2008     Kolkata  20-04-2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...
